# %% [markdown]
# ## illuma Price Comparison Data Analysis

# %%
import pandas as pd
import numpy as np
import string
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

df = pd.read_csv('./data_cleaned.csv')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
df
# Out:
#                                                                                    Title  \
# 0                                         [新版]惠氏illuma 啟賦 1段 0-6個月 850g(new packing) 4階段
# 1                                                              惠氏illuma 啟賦 4段 3歲以上 850g.
# 2                                       illuma luxa hmo 1號初生嬰兒配方奶粉 (6種hmo) 850克買滿$399免運費
# 3                                            原装行貨-惠氏港版illuma luxa 3號 兒童成長配方奶粉 850g (6罐裝)
# 4                                                                    illuma hmo初生嬰兒配方奶粉1
# 5                                                            惠氏illuma 啟賦 2段 6-12個月 850g.
# 6                  illuma-(2021 新包裝) 惠氏 illuma luxa 啟賦 850g #2號 x 1罐 [香港行貨] (2021 新包 ...
# 7                                                       illuma 有機 嬰兒配方奶粉 900克(0-6個月) 1階段
# 8                                                        illuma 有機幼兒成長配方奶粉 850克買滿$399免運費
# ...

# %%
stage1_luxa = df.loc[np.where((df['Stage']==1) & (df['Series']=="Luxa") & (df["Can"]==1))].sort_values(by = "Unit Price")
#stage1_luxa[stage1_luxa["Unit Price"] == stage1_luxa["Unit Price"].min()]
stage1_luxa
# Out:
#                                                                      Title  \
# 0                           [新版]惠氏illuma 啟賦 1段 0-6個月 850g(new packing) 4階段
# 16            illuma-香港行貨 惠氏 illuma luxa 啟賦#1 850g 香港行貨 惠氏 illuma啟賦#1 850g
# 9                                                         illuma 配方奶粉 - 1號
# 2                         illuma luxa hmo 1號初生嬰兒配方奶粉 (6種hmo) 850克買滿$399免運費
# 28                                   惠氏 illuma luxa 1號 初生嬰兒配方奶粉 850g (新包裝)
# 71                                 illuma luxa stage 1 infant formula 850g
# 49  illuma-啟賦 luxa 初生嬰兒配方奶粉 1 階段 850g [新裝] 啟賦 luxa 初生嬰兒配方奶粉 1 階段 850g [新裝]
# 54                                   愛爾蘭 illuma 未來版啟賦hmo嬰幼兒配方奶粉 1段 850g 淺藍
# 4                                                      illuma hmo初生嬰兒配方奶粉1
#
#     Price           Merchant Series  Can  Stage Parallel Import  \
# 0   285.0        Thai Ho Pai   Luxa    1      1      not stated
# 16  410.0           HKTVmall   Luxa    1      1           False
# ...

# %%
stage2_luxa = df.loc[np.where((df['Stage']==2) & (df['Series']=="Luxa") & (df["Can"]==1))].sort_values(by = "Unit Price")
#stage2_luxa[stage2_luxa["Unit Price"] == stage2_luxa["Unit Price"].min()]
stage2_luxa
# Out:
#                                                                                    Title  \
# 20                                                     illuma 未來版啟賦hmo嬰幼兒配方奶粉 2段 850g 淺藍
# 5                                                            惠氏illuma 啟賦 2段 6-12個月 850g.
# 6                  illuma-(2021 新包裝) 惠氏 illuma luxa 啟賦 850g #2號 x 1罐 [香港行貨] (2021 新包 ...
# 25                                                                      illuma 配方奶粉 - 2號
# 32                         illuma-惠氏 - (全新裝)illuma hmo #2 號 850g (較大嬰兒配方奶粉)(香港正貨) 惠氏 ...
# 45                                                            惠氏 illuma 2號 較大嬰兒配方奶粉 850g
# 48                wyeth 惠氏 - illuma啟賦 2號 較大嬰兒配方奶粉 850g - lifestyle | nursing-feeding ...
# 11                                      illuma luxa hmo 2號較大嬰兒配方奶粉 (6種hmo) 850克買滿$399免運費
# 52  illuma-luxa hmo 2號較大嬰兒配方奶粉 850克 (6種hmo) (新/舊包裝隨機發貨)illuma以嶄新科技還原大自然的親和力量,支持寶寶綻放無窮天賦。
# ...

# %%
stage3_luxa = df.loc[np.where((df['Stage']==3) & (df['Series']=="Luxa") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage3_luxa[stage3_luxa["Unit Price"] == stage3_luxa["Unit Price"].min()]
# Out:
#                Title  Price      Merchant Series  Can  Stage Parallel Import  \
# 34  illuma 配方奶粉 - 3號  345.0  Mamy Kingdom   Luxa    1      3      not stated
#
#    Parellel Import  Unit Price Merchant Type
# 34             NaN       345.0        Others

# %%
stage4_luxa = df.loc[np.where((df['Stage']==4) & (df['Series']=="Luxa") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage4_luxa#[stage4_luxa["Unit Price"] == stage4_luxa["Unit Price"].min()]
# Out:
#                                                                Title  Price  \
# 60                    [新版]惠氏illuma 啟賦 1段 0-6個月 850g(new packing) 4階段  285.0
# 1                                          惠氏illuma 啟賦 4段 3歲以上 850g.  305.0
# 26                             愛爾蘭 illuma 未來版啟賦hmo嬰幼兒配方奶粉 4段 850g 淺藍  315.0
# 27  illuma-(最新包裝) illuma啟賦#4 luxa 850g [香港行貨] illuma啟賦#4 850g [香港行貨]  340.0
# 30                                                  illuma 配方奶粉 - 4號  340.0
# 70                       illuma luxa stage 4 growing-up formula 850g  353.0
# 39                          惠氏 illuma - illuma luxa 4號 兒童成長配方奶粉 850g  355.0
# 19                                               illuma hmo學兒成長配方奶粉4  405.0
#
#            Merchant Series  Can  Stage Parallel Import Parellel Import  \
# 60      Thai Ho Pai   Luxa    1      4      not stated             NaN
# 1       Thai Ho Pai   Luxa    1      4      not stated             NaN
# ...

# %%
stage1_org = df.loc[np.where((df['Stage']==1) & (df['Series']=="Organic") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage1_org[stage1_org["Unit Price"] == stage1_org["Unit Price"].min()]
# Out:
#                              Title  Price       Merchant   Series  Can  Stage  \
# 8  illuma 有機幼兒成長配方奶粉 850克買滿$399免運費  439.0  PARKnSHOP.com  Organic    1      1
#
#   Parallel Import Parellel Import  Unit Price Merchant Type
# 8           False             NaN       439.0         Chain

# %%
stage2_org = df.loc[np.where((df['Stage']==2) & (df['Series']=="Organic") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage2_org[stage2_org["Unit Price"] == stage2_org["Unit Price"].min()]
# Out:
#                                Title  Price     Merchant   Series  Can  Stage  \
# 13  illuma 有機 較大嬰兒配方奶粉 900克(6個月至1歲).  458.0  Thai Ho Pai  Organic    1      2
#
#    Parallel Import Parellel Import  Unit Price Merchant Type
# 13      not stated             NaN       458.0        Others

# %%
stage3_org = df.loc[np.where((df['Stage']==3) & (df['Series']=="Organic") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage3_org[stage3_org["Unit Price"] == stage3_org["Unit Price"].min()]
# Out:
#                                 Title  Price Merchant   Series  Can  Stage  \
# 42  【香港行貨 】illuma 3號 有機幼兒成長配方奶粉 850 g  429.9   Halook  Organic    1      3
#
#    Parallel Import Parellel Import  Unit Price Merchant Type
# 42           False             NaN       429.9        Others

# %%
stage1_atwo = df.loc[np.where((df['Stage']==1) & (df['Series']=="Atwo") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage1_atwo
#stage1_atwo[stage1_atwo["Unit Price"] == stage1_atwo["Unit Price"].min()]
# Out:
#                                                           Title  Price  \
# 33          illuma illuma atwo a2 β-酪蛋白1號初生嬰兒配方奶粉 850克買滿$399免運費  538.0
# 38                          illuma atwo a2 β-酪蛋白1號初生嬰兒配方奶粉 850克  538.0
# 56  illuma-親和人體a2 β-酪蛋白配方 初生嬰兒配方奶粉 (新款:850g/舊款:900g) (款式隨機發 ...  538.0
# 67                      illuma atwo stage 1 infant formula 850g  538.0
#
#              Merchant Series  Can  Stage Parallel Import Parellel Import  \
# 33  Watsons Hong Kong   Atwo    1      1           False             NaN
# 38           Tmall HK   Atwo    1      1      not stated             NaN
# 56           HKTVmall   Atwo    1      1      not stated             NaN
# 67           Mannings   Atwo    1      1           False             NaN
#
#     Unit Price Merchant Type
# 33       538.0         Chain
# 38       538.0        Others
# 56       538.0        Others
# 67       538.0         Chain

# %%
stage2_atwo = df.loc[np.where((df['Stage']==2) & (df['Series']=="Atwo") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage2_atwo[stage2_atwo["Unit Price"] == stage2_atwo["Unit Price"].min()]
# Out:
#                                          Title  Price       Merchant Series  \
# 43  illuma illuma atwo a2 β-酪蛋白2號較大嬰兒配方奶粉 850克  476.0  PARKnSHOP.com   Atwo
#
#     Can  Stage Parallel Import Parellel Import  Unit Price Merchant Type
# 43    1      2           False             NaN       476.0         Chain

# %%
stage3_atwo = df.loc[np.where((df['Stage']==3) & (df['Series']=="Atwo") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage3_atwo[stage3_atwo["Unit Price"] == stage3_atwo["Unit Price"].min()]
# Out:
#                                          Title  Price       Merchant Series  \
# 58  illuma illuma atwo a2 β-酪蛋白3號幼兒成長配方奶粉 850克  427.0  PARKnSHOP.com   Atwo
#
#     Can  Stage Parallel Import Parellel Import  Unit Price Merchant Type
# 58    1      3           False             NaN       427.0         Chain

# %%
stage4_atwo = df.loc[np.where((df['Stage']==4) & (df['Series']=="Atwo") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage4_atwo[stage4_atwo["Unit Price"] == stage4_atwo["Unit Price"].min()]
# Out:
#                                           Title  Price  Merchant Series  Can  \
# 65  illuma atwo stage 4 growing-up formula 850g  405.0  Mannings   Atwo    1
#
#     Stage Parallel Import Parellel Import  Unit Price Merchant Type
# 65      4           False             NaN       405.0         Chain

# %%
stage1_ha = df.loc[np.where((df['Stage']==1) & (df['Series']=="HA") & (df["Can"]==1))].sort_values(by = "Unit Price")
stage1_ha[stage1_ha["Unit Price"] == stage1_ha["Unit Price"].min()]
# Out:
#                                                              Title  Price  \
# 47  illuma-惠氏 illuma 親和人體 (ha低敏配方) (0-12個月) 800克 (到期日:2022年4月後 ...  488.0
#
#     Merchant Series  Can  Stage Parallel Import Parellel Import  Unit Price  \
# 47  HKTVmall     HA    1      1      not stated             NaN       488.0
#
#    Merchant Type
# 47        Others

# %%
can6 = df.loc[np.where((df["Can"]==6) & (df['Series']=="Luxa"))].sort_values(by = "Stage")
can6
# Out:
#                                                 Title   Price     Merchant  \
# 18        原装行貨-惠氏港版illuma luxa 1號 兒童成長配方奶粉 850g (6罐裝)  2220.0  Parpee Shop
# 79  wyeth 惠氏 - illuma luxa stage 1 初生嬰兒配方奶粉 850g (6罐)  3228.0         Sogo
# 10    原装行貨-惠氏港版illuma luxa stage 2號 嬰兒配方奶粉 850g (6罐裝)  2010.0  Parpee Shop
# 44                    illuma - luxa hmo 2號/3號/4號 x 6罐  2430.0     Tmall HK
# 82  wyeth 惠氏 - illuma luxa stage 2 較大嬰兒配方奶粉 850g (6罐)  2952.6         Sogo
# 3         原装行貨-惠氏港版illuma luxa 3號 兒童成長配方奶粉 850g (6罐裝)  1770.0  Parpee Shop
# 81  wyeth 惠氏 - illuma luxa stage 3 幼兒成長配方奶粉 850g (6罐)  2650.5         Sogo
# 12             原装行貨-惠氏港版illuma 4號 兒童成長配方奶粉 850g (6罐裝)  1770.0  Parpee Shop
# 80  wyeth 惠氏 - illuma luxa stage 4 學兒成長配方奶粉 850g (6罐)  2308.5         Sogo
#
#    Series  Can  Stage Parallel Import Parellel Import  Unit Price  \
# 18   Luxa    6      1      not stated             NaN      370.00
# 79   Luxa    6      1             NaN           False      538.00
# ...

# %%
can_or = df.loc[np.where((df["Can"]==6) & (df['Series']=="Organic"))].sort_values(by = "Stage")
can_or
# Out:
#                                                    Title   Price Merchant  \
# 74  wyeth 惠氏 - illuma organic stage 1 初生嬰兒配方奶粉 850g (6罐)  3534.0     Sogo
# 84  wyeth 惠氏 - illuma organic stage 2 較大嬰兒配方奶粉 850g (6罐)  3186.3     Sogo
# 83  wyeth 惠氏 - illuma organic stage 3 幼兒成長配方奶粉 850g (6罐)  2844.3     Sogo
#
#      Series  Can  Stage Parallel Import Parellel Import  Unit Price  \
# 74  Organic    6      1             NaN           False      589.00
# 84  Organic    6      2             NaN           False      531.05
# 83  Organic    6      3             NaN           False      474.05
#
#    Merchant Type
# 74         Chain
# 84         Chain
# 83         Chain

# %%
can_atwo = df.loc[np.where((df["Can"]==6) & (df['Series']=="Atwo"))].sort_values(by = "Stage")
can_atwo
# Out:
#                                                 Title   Price Merchant Series  \
# 78  wyeth 惠氏 - illuma atwo stage 1 初生嬰兒配方奶粉 850g (6罐)  3228.0     Sogo   Atwo
# 77  wyeth 惠氏 - illuma atwo stage 2 較大嬰兒配方奶粉 850g (6罐)  2952.6     Sogo   Atwo
# 76  wyeth 惠氏 - illuma atwo stage 3 幼兒成長配方奶粉 850g (6罐)  2650.5     Sogo   Atwo
# 75  wyeth 惠氏 - illuma atwo stage 4 學兒成長配方奶粉 850g (6罐)  2308.5     Sogo   Atwo
#
#     Can  Stage Parallel Import Parellel Import  Unit Price Merchant Type
# 78    6      1             NaN           False      538.00         Chain
# 77    6      2             NaN           False      492.10         Chain
# 76    6      3             NaN           False      441.75         Chain
# 75    6      4             NaN           False      384.75         Chain

# %%
can_atwo = df.loc[np.where((df["Can"]==6) & (df['Series']=="HA"))].sort_values(by = "Stage")
can_atwo
# Out:
# Empty DataFrame
# Columns: [Title, Price, Merchant, Series, Can, Stage, Parallel Import, Parellel Import, Unit Price, Merchant Type]
# Index: []
